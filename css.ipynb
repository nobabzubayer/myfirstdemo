# %% [markdown]
# <a href="https://colab.research.google.com/github/nobabzubayer/myfirstdemo/blob/main/css.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
* {
  margin: 0;
  padding: 0;
  box-sizing: border-box;
  font-family: 'Inter', sans-serif;
}

body {
  background: #ffffff;
  color: #111111;
}

.navbar {
  height: 88px;
  border-bottom: 1px solid #e9e9e9;
  display: flex;
  justify-content: space-between;
  align-items: center;
  padding: 0 18px;
}

.nav-left {
  display: flex;
  align-items: center;
  gap: 30px;
}

.logo {
  width: 26px;
  height: 26px;
  position: relative;
}

.dot {
  position: absolute;
  width: 12px;
  height: 12px;
  border-radius: 999px;
}

.red {
  background: #ff5c39;
  top: 0;
  left: 0;
  width: 18px;
  height: 10px;
  border-radius: 20px;
}

.purple {
  background: #a259ff;
  top: 9px;
  left: 0;
}

.blue {
  background: #1abcfe;
  top: 9px;
  left: 13px;
}

.green {
  background: #0acf83;
  top: 18px;
  left: 0;
  width: 10px;
  height: 10px;
}

.nav-menu {
  display: flex;
  gap: 28px;
}

.nav-menu a {
  text-decoration: none;
  color: #111;
  font-size: 16px;
  font-weight: 400;
}

.nav-menu a span {
  font-size: 12px;
}

.nav-right {
  display: flex;
  align-items: center;
  gap: 18px;
}

.logout {
  text-decoration: none;
  color: #111;
  font-size: 16px;
}

.contact-btn {
  padding: 14px 24px;
  border: 1.5px solid #111;
  border-radius: 12px;
  background: white;
  font-size: 16px;
  cursor: pointer;
}

.profile {
  width: 46px;
  height: 46px;
  border-radius: 50%;
  background: #07998f;
  color: white;
  display: flex;
  align-items: center;
  justify-content: center;
  font-size: 20px;
  font-weight: 500;
}

.hero {
  display: flex;
  flex-direction: column;
  align-items: center;
  justify-content: flex-start;
  min-height: calc(100vh - 88px);
  padding-top: 120px;
}

.hero h1 {
  text-align: center;
  font-size: 64px;
  font-weight: 400;
  line-height: 1.15;
  color: #111;
}

.icon-box {
  display: inline-flex;
  align-items: center;
  justify-content: center;
  width: 56px;
  height: 56px;
  background: #dfe6ef;
  border-radius: 10px;
  font-size: 34px;
  vertical-align: middle;
}

.prompt-box {
  margin-top: 38px;
  width: 680px;
  height: 225px;
  border: 2px solid #111;
  border-radius: 28px;
  position: relative;
  background: #fff;
  box-shadow: 0 0 40px rgba(0, 0, 0, 0.05);
}

.prompt-box textarea {
  width: 100%;
  height: 100%;
  border: none;
  outline: none;
  resize: none;
  border-radius: 28px;
  padding: 24px;
  font-size: 20px;
  background: transparent;
}

.arrow-btn {
  position: absolute;
  right: 18px;
  bottom: 16px;
  width: 46px;
  height: 46px;
  border-radius: 50%;
  border: none;
  background: #efefef;
  color: #b3b3b3;
  font-size: 28px;
  cursor: pointer;
}

@media (max-width: 900px) {
  .nav-menu {
    display: none;
  }

  .hero h1 {
    font-size: 42px;
    padding: 0 20px;
  }

  .prompt-box {
    width: 90%;
    height: 200px;
  }
}
